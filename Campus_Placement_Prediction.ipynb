# %%
import pandas as pd

# %%
data = pd.read_csv('Placement.csv')

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1. Display Top 5 Rows of The Dataset

# %%
data.head()
# Out:
#    sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1       0  67.00   Others  91.00   Others  Commerce     58.00
# 1      2       0  79.33  Central  78.33   Others   Science     77.48
# 2      3       0  65.00  Central  68.00  Central      Arts     64.00
# 3      4       0  56.00  Central  52.00  Central   Science     52.00
# 4      5       0  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %% [markdown]
# ### 2. Check Last 5 Rows of The Dataset

# %%
data.tail()
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  \
# 210    211       0   80.6   Others   82.0  Others  Commerce      77.6
# 211    212       0   58.0   Others   60.0  Others   Science      72.0
# 212    213       0   67.0   Others   67.0  Others  Commerce      73.0
# 213    214       1   74.0   Others   66.0  Others  Commerce      58.0
# 214    215       0   62.0  Central   58.0  Others   Science      53.0
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN

# %% [markdown]
# ### 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)

# %%
data.shape
# Out:
# (215, 15)

# %%
print("Number of Rows",data.shape[0])
print("Number of Columns",data.shape[1])
# Out:
# Number of Rows 215
# Number of Columns 15

# %% [markdown]
# ### 4. Get Information About Our Dataset Like the Total Number of Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    int64
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(2), object(7)
# memory usage: 25.3+ KB

# %% [markdown]
# ### 5. Check Null Values In The Dataset

# %%
data.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# ### 6. Get Overall Statistics About The Dataset

# %%
data.describe()
# Out:
#             sl_no      gender       ssc_p       hsc_p    degree_p     etest_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000    0.353488   67.303395   66.333163   66.370186   72.100558
# std     62.209324    0.479168   10.827205   10.897509    7.358743   13.275956
# min      1.000000    0.000000   40.890000   37.000000   50.000000   50.000000
# 25%     54.500000    0.000000   60.600000   60.900000   61.000000   60.000000
# 50%    108.000000    0.000000   67.000000   65.000000   66.000000   71.000000
# 75%    161.500000    1.000000   75.700000   73.000000   72.000000   83.500000
# max    215.000000    1.000000   89.400000   97.700000   91.000000   98.000000
#
#             mba_p         salary
# count  215.000000     148.000000
# mean    62.278186  288655.405405
# std      5.833385   93457.452420
# min     51.210000  200000.000000
# 25%     57.945000  240000.000000
# 50%     62.000000  265000.000000
# ...

# %% [markdown]
# ### 7. EDA

# %%
data.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %% [markdown]
# #### How Many Students Got Placed?

# %%
data['status'].unique()
# Out:
# array(['Placed', 'Not Placed'], dtype=object)

# %%
data['status'].value_counts()
# Out:
# status
# Placed        148
# Not Placed     67
# Name: count, dtype: int64

# %% [markdown]
# #### Could you display the top 5 sci&tech students placed according to their salary?

# %%
data.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
data[(data['degree_t']=="Sci&Tech") & (data['status']=="Placed")].sort_values(by="salary",ascending=False).head()
# Out:
#      sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b    hsc_s  degree_p  \
# 150    151       0  71.00  Central  58.66  Central  Science     58.00
# 174    175       0  73.24   Others  50.83   Others  Science     64.27
# 163    164       0  63.00   Others  67.00   Others  Science     64.00
# 77      78       0  64.00   Others  80.00   Others  Science     65.00
# 53      54       0  80.00   Others  70.00   Others  Science     72.00
#
#      degree_t workex  etest_p specialisation  mba_p  status    salary
# 150  Sci&Tech    Yes     56.0        Mkt&Fin  61.30  Placed  690000.0
# 174  Sci&Tech    Yes     64.0        Mkt&Fin  66.23  Placed  500000.0
# 163  Sci&Tech     No     75.0        Mkt&Fin  66.46  Placed  500000.0
# 77   Sci&Tech    Yes     69.0        Mkt&Fin  57.65  Placed  500000.0
# 53   Sci&Tech     No     87.0         Mkt&HR  71.04  Placed  450000.0

# %% [markdown]
# ### 8. Data Preprocessing

# %%
data.head()
# Out:
#    sl_no  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1       0  67.00   Others  91.00   Others  Commerce     58.00
# 1      2       0  79.33  Central  78.33   Others   Science     77.48
# 2      3       0  65.00  Central  68.00  Central      Arts     64.00
# 3      4       0  56.00  Central  52.00  Central   Science     52.00
# 4      5       0  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
data = data.drop(['sl_no','salary'],axis=1)

# %%
data.head(1)
# Out:
#    gender  ssc_p   ssc_b  hsc_p   hsc_b     hsc_s  degree_p  degree_t workex  \
# 0       0   67.0  Others   91.0  Others  Commerce      58.0  Sci&Tech     No
#
#    etest_p specialisation  mba_p  status
# 0     55.0         Mkt&HR   58.8  Placed

# %% [markdown]
# #### Encoding the Categorical Columns

# %%
data['ssc_b'].unique()
# Out:
# array(['Others', 'Central'], dtype=object)

# %%
data['ssc_b'] = data['ssc_b'].map({'Central':1,'Others':0})

# %%
data.head(2)
# Out:
#    gender  ssc_p  ssc_b  hsc_p   hsc_b     hsc_s  degree_p  degree_t workex  \
# 0       0  67.00      0  91.00  Others  Commerce     58.00  Sci&Tech     No
# 1       0  79.33      1  78.33  Others   Science     77.48  Sci&Tech    Yes
#
#    etest_p specialisation  mba_p  status
# 0     55.0         Mkt&HR  58.80  Placed
# 1     86.5        Mkt&Fin  66.28  Placed

# %%
data['hsc_b'].unique()
# Out:
# array(['Others', 'Central'], dtype=object)

# %%
data['hsc_b'] = data['hsc_b'].map({'Central':1,'Others':0})

# %%
data.head(2)
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b     hsc_s  degree_p  degree_t workex  \
# 0       0  67.00      0  91.00      0  Commerce     58.00  Sci&Tech     No
# 1       0  79.33      1  78.33      0   Science     77.48  Sci&Tech    Yes
#
#    etest_p specialisation  mba_p  status
# 0     55.0         Mkt&HR  58.80  Placed
# 1     86.5        Mkt&Fin  66.28  Placed

# %%
data['hsc_s'].unique()
# Out:
# array(['Commerce', 'Science', 'Arts'], dtype=object)

# %%
data['hsc_s'] = data['hsc_s'].map({'Science':2,'Commerce':1,'Arts':0})

# %%
data.head()
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p   degree_t workex  \
# 0       0  67.00      0  91.00      0      1     58.00   Sci&Tech     No
# 1       0  79.33      1  78.33      0      2     77.48   Sci&Tech    Yes
# 2       0  65.00      1  68.00      1      0     64.00  Comm&Mgmt     No
# 3       0  56.00      1  52.00      1      2     52.00   Sci&Tech     No
# 4       0  85.80      1  73.60      1      1     73.30  Comm&Mgmt     No
#
#    etest_p specialisation  mba_p      status
# 0     55.0         Mkt&HR  58.80      Placed
# 1     86.5        Mkt&Fin  66.28      Placed
# 2     75.0        Mkt&Fin  57.80      Placed
# 3     66.0         Mkt&HR  59.43  Not Placed
# 4     96.8        Mkt&Fin  55.50      Placed

# %%
data['degree_t'].unique()
# Out:
# array(['Sci&Tech', 'Comm&Mgmt', 'Others'], dtype=object)

# %%
data['degree_t'] = data['degree_t'].map({'Sci&Tech':2,'Comm&Mgmt':1,'Others':0})

# %%
data.head(2)
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t workex  \
# 0       0  67.00      0  91.00      0      1     58.00         2     No
# 1       0  79.33      1  78.33      0      2     77.48         2    Yes
#
#    etest_p specialisation  mba_p  status
# 0     55.0         Mkt&HR  58.80  Placed
# 1     86.5        Mkt&Fin  66.28  Placed

# %%
data['specialisation'].unique()
# Out:
# array(['Mkt&HR', 'Mkt&Fin'], dtype=object)

# %%
data['specialisation'] =data['specialisation'].map({'Mkt&HR':1,'Mkt&Fin':0})

# %%
data.head(2)
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t workex  \
# 0       0  67.00      0  91.00      0      1     58.00         2     No
# 1       0  79.33      1  78.33      0      2     77.48         2    Yes
#
#    etest_p  specialisation  mba_p  status
# 0     55.0               1  58.80  Placed
# 1     86.5               0  66.28  Placed

# %%
data['workex'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['workex'] = data['workex'].map({'Yes':1,'No':0})

# %%
data.head(2)
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0       0  67.00      0  91.00      0      1     58.00         2       0
# 1       0  79.33      1  78.33      0      2     77.48         2       1
#
#    etest_p  specialisation  mba_p  status
# 0     55.0               1  58.80  Placed
# 1     86.5               0  66.28  Placed

# %%
data['status'].unique()
# Out:
# array(['Placed', 'Not Placed'], dtype=object)

# %%
data['status'] = data['status'].map({'Placed':1,'Not Placed':0})

# %%
data.head()
# Out:
#    gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# 0       0  67.00      0  91.00      0      1     58.00         2       0
# 1       0  79.33      1  78.33      0      2     77.48         2       1
# 2       0  65.00      1  68.00      1      0     64.00         1       0
# 3       0  56.00      1  52.00      1      2     52.00         2       0
# 4       0  85.80      1  73.60      1      1     73.30         1       0
#
#    etest_p  specialisation  mba_p  status
# 0     55.0               1  58.80       1
# 1     86.5               0  66.28       1
# 2     75.0               0  57.80       1
# 3     66.0               1  59.43       0
# 4     96.8               0  55.50       1

# %% [markdown]
# ### 9. Store Feature Matrix In X and Response(Target) In Vector y

# %%
data.columns
# Out:
# Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',
#        'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status'],
#       dtype='object')

# %%
X = data.drop('status',axis=1)
y= data['status']

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 210    1
# 211    1
# 212    1
# 213    1
# 214    0
# Name: status, Length: 215, dtype: int64

# %% [markdown]
# ### 10. Splitting The Dataset Into The Training Set And Test Set

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %% [markdown]
# ### 11. Import The models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %% [markdown]
# ### 12. Model Training

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)

svm = svm.SVC()
svm.fit(X_train,y_train)

knn=KNeighborsClassifier()
knn.fit(X_train,y_train)

dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)

rf=RandomForestClassifier()
rf.fit(X_train,y_train)

gb=GradientBoostingClassifier()
gb.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier()

# %% [markdown]
# ### 13. Prediction on Test Data

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = svm.predict(X_test)
y_pred3 = knn.predict(X_test)
y_pred4 = dt.predict(X_test)
y_pred5 = rf.predict(X_test)
y_pred6 = gb.predict(X_test)

# %% [markdown]
# ### 14. Evaluating the Algorithms

# %%
from sklearn.metrics import accuracy_score #here we use accuracy_score because it is a classification problem

# %%
score1=accuracy_score(y_test,y_pred1)
score2=accuracy_score(y_test,y_pred2)
score3=accuracy_score(y_test,y_pred3)
score4=accuracy_score(y_test,y_pred4)
score5=accuracy_score(y_test,y_pred5)
score6=accuracy_score(y_test,y_pred6)

# %%
print(score1,score2,score3,score4,score5,score6)
# Out:
# 0.8837209302325582 0.7674418604651163 0.7906976744186046 0.8372093023255814 0.7906976744186046 0.813953488372093

# %%
final_data = pd.DataFrame({'Models':['LR','SVC','KNN','DT','RF','GB'],
            'ACC':[score1*100,
                  score2*100,
                  score3*100,
                  score4*100,
                  score5*100,score6*100]})

# %%
final_data
# Out:
#   Models        ACC
# 0     LR  88.372093
# 1    SVC  76.744186
# 2    KNN  79.069767
# 3     DT  83.720930
# 4     RF  79.069767
# 5     GB  81.395349

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x='Models',
    y='ACC',
    data=final_data,
    palette='viridis',
    edgecolor="black"
)

for index, row in final_data.iterrows():
    plt.text(index, row.ACC + 0.01, round(row.ACC, 2), 
             ha='center', fontsize=10, fontweight='bold')


plt.title("Model Accuracy Comparison", fontsize=14, fontweight='bold')
plt.xlabel("Models", fontsize=12)
plt.ylabel("Accuracy", fontsize=12)


plt.show()

# %% [markdown]
# ### 15. Prediction on New Data

# %%
new_data = pd.DataFrame({
    'gender':0,
    'ssc_p':67.0,
    'ssc_b':0,
    'hsc_p':91.0,
    'hsc_b':0,
    'hsc_s':1,
    'degree_p':58.0,
    'degree_t':2,
    'workex':0,
    'etest_p':55.0,
    'specialisation':1,
    'mba_p':58.8,   
},index=[0])

# %%
lr= LogisticRegression()
lr.fit(X,y)
# Out:
# LogisticRegression()

# %%
p=lr.predict(new_data)
prob=lr.predict_proba(new_data)
if p==1:
    print('Placed')
    print(f"You will be placed with probability of {prob[0][1]:.2f}")
else:
    print("Not-placed")
# Out:
# Placed
# You will be placed with probability of 0.97

# %%
prob
# Out:
# array([[0.03408921, 0.96591079]])

# %% [markdown]
# ### 16. Save Model Using Joblib

# %%
import joblib

# %%
joblib.dump(lr,'model_campus_placement')
# Out:
# ['model_campus_placement']

# %%
model = joblib.load('model_campus_placement')

# %%
model.predict(new_data)
# Out:
# array([1])

# %% [markdown]
# ### GUI

# %%
from tkinter import *
import joblib
import pandas as pd
import tkinter.font as font

# Prediction Function
def show_entry_fields():
    text = clicked.get()
    p1 = 1 if text == "Male" else 0

    p2 = float(e2.get())
    p3 = 1 if clicked1.get() == "Central" else 0
    p4 = float(e4.get())
    p5 = 1 if clicked6.get() == "Central" else 0

    text = clicked2.get()
    p6 = 2 if text == "Science" else (1 if text == "Commerce" else 0)

    p7 = float(e7.get())
    text = clicked3.get()
    p8 = 2 if text == "Sci&Tech" else (1 if text == "Comm&Mgmt" else 0)

    p9 = 1 if clicked4.get() == "Yes" else 0
    p10 = float(e10.get())
    p11 = 1 if clicked5.get() == "Mkt&HR" else 0
    p12 = float(e12.get())

    # Load model
    model = joblib.load('model_campus_placement')

    new_data = pd.DataFrame({
        'gender': [p1],
        'ssc_p': [p2],
        'ssc_b': [p3],
        'hsc_p': [p4],
        'hsc_b': [p5],
        'hsc_s': [p6],
        'degree_p': [p7],
        'degree_t': [p8],
        'workex': [p9],
        'etest_p': [p10],
        'specialisation': [p11],
        'mba_p': [p12],
    })

    result = model.predict(new_data)
    result1 = model.predict_proba(new_data)

    if result[0] == 0:
        result_label.config(
            text="❌ Student may NOT be Placed",
            fg="red", font=("Arial", 16, "bold")
        )
    else:
        result_label.config(
            text=f"✅ Student will be Placed\nProbability: {round(result1[0][1]*100, 2)}%",
            fg="green", font=("Arial", 16, "bold")
        )

# Main Window
master = Tk()
master.title("Campus Placement Prediction System")
master.geometry("700x700")
master.config(bg="#f0f0f5")

# Title Banner
title = Label(
    master,
    text="🎓 Campus Placement Prediction System 🎓",
    bg="#4CAF50", fg="white",
    font=("Arial", 22, "bold"),
    pady=15
)
title.pack(fill=X)

# Form Frame
form_frame = Frame(master, bg="#f0f0f5", padx=20, pady=20)
form_frame.pack(pady=20)

# Dropdowns and Entries
labels = [
    "Gender", "Secondary Education % (10th)", "Board of Education (10th)",
    "Higher Secondary % (12th)", "Board of Education (12th)",
    "HSC Specialization", "Degree %", "UG Degree Type",
    "Work Experience", "E-test %", "MBA Specialisation", "MBA %"
]

# Options
clicked = StringVar(); options = ["Male","Female"]
clicked1 = StringVar(); options1 = ["Central","Others"]
clicked2 = StringVar(); options2 = ["Science","Commerce","Arts"]
clicked3 = StringVar(); options3 = ["Sci&Tech","Comm&Mgmt","Others"]
clicked4 = StringVar(); options4 = ["Yes","No"]
clicked5 = StringVar(); options5 = ["Mkt&HR","Mky&Fin"]
clicked6 = StringVar(); options6 = ["Central","Others"]

entries = []

widgets = [
    OptionMenu(form_frame, clicked, *options),
    Entry(form_frame),
    OptionMenu(form_frame, clicked1, *options1),
    Entry(form_frame),
    OptionMenu(form_frame, clicked6, *options6),
    OptionMenu(form_frame, clicked2, *options2),
    Entry(form_frame),
    OptionMenu(form_frame, clicked3, *options3),
    OptionMenu(form_frame, clicked4, *options4),
    Entry(form_frame),
    OptionMenu(form_frame, clicked5, *options5),
    Entry(form_frame)
]

# Assign variables
e1,e2,e3,e4,e5,e6,e7,e8,e9,e10,e11,e12 = widgets

# Styling inputs
for w in widgets:
    w.config(width=20, font=("Arial", 12))

# Placing labels + inputs in grid
for i, text in enumerate(labels):
    Label(form_frame, text=text, font=("Arial", 13), bg="#f0f0f5").grid(row=i, column=0, sticky=W, pady=5)
    widgets[i].grid(row=i, column=1, pady=5, padx=10)

# Predict Button
buttonFont = font.Font(family='Helvetica', size=16, weight='bold')
predict_btn = Button(
    master, text="Predict", height=2, width=15,
    activebackground="#00cc66",
    font=buttonFont, bg="black", fg="white",
    command=show_entry_fields
)
predict_btn.pack(pady=20)

# Result Label
result_label = Label(master, text="", bg="#f0f0f5", font=("Arial", 14))
result_label.pack(pady=10)

master.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\SUBHAJIT ROY\AppData\Local\Programs\Python\Python313\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\SUBHAJIT ROY\AppData\Local\Temp\ipykernel_16440\1999041630.py", line 11, in show_entry_fields
#     p2 = float(e2.get())
# ValueError: could not convert string to float: ''
